# %%
import pandas as pd

# %%
df = pd.read_csv('./submissions/cv5fold.csv')

# %%
df
# Out:
#                     id                              attribute_ids
# 0     10023b2cc4ed5f68           195 223 289 344 369 587 766 1059
# 1     100fbe75ed8fd887                                   231 1039
# 2     101b627524a04f19                         79 180 498 728 784
# 3     10234480c41284c6     13 51 147 483 725 738 776 813 830 1046
# 4     1023b0e2636dcea8  147 322 501 584 737 776 813 954 1046 1092
# 5      1039cd6cf85845c                        13 405 896 903 1092
# 6      103a5b3f83fbe88                  194 671 744 813 1046 1092
# 7     10413aaae8d6a9a2                          147 813 1046 1092
# 8     10423822b93a65ab                                        147
# 9     1052bf702cb099f7                       188 335 597 813 1092
# 10     10543c918a43a8d               147 189 541 580 813 993 1092
# 11    105c9a3453da79c3                                121 464 840
# 12    1060688bbf6eac87       189 418 542 731 796 934 940 949 1072
# ...
